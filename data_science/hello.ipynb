# %% [markdown]
# Saturn Notebooks
# The Ed platform uses a slightly modified version of project Jupyter which they call Saturn.
#
# You can add new code cells, or markdown cells using the interface.
#
# We encourage you to play around the interface. You will be using this for all of your programming assignments.

# %%
print("Hello World")
# Out:
# Hello World
